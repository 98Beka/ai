# %% [markdown]
# # Task_1
#
# Дан список чисел. Напишите функцию, которая выполняет для каждого элемента списка следующие действия:
#
# * Если число четное, то прибавляет к нему 1
#
# * Если число нечетное, то возвращает его как есть.
#
# Приментие функцию к каждому элементу по отдельности.

# %%
list_ = [3, 5, 4, 6, 5, 3, 4, 5, 8, 6, 3]

# %% [markdown]
# # Task_2
#
# Дан список чисел. Напишите функцию, которая получает на вход число и проверяет, простое оно или нет и возвращает True и False соответственно. Напишите такую функцию и примените к каждому элементу списка. Все результаты сложите в новый список.

# %%
list_ = [12, 13, 15, 17, 23, 29, 101, 100, 599, 251]

# %% [markdown]
# # Task_3
#
# Напишите функцию, которая получает на вход список и возвращает среднее арифметическое всех чисел списка. С помощью этой функции отредактируйте словарь заменив в нем значения на соответствующее среднее.

# %%
dict_ = {'n_1': [23, 13, 24, 35, 24, 26, 27],
         'n_2': [1, 4, 3, 5, 4, 3, 6],
         'n_3': [100, 234, 342, 563, 342]}

# %% [markdown]
# # Task_4
#
# Дана зависимость:
#
# $$y = \frac{x^2-2x-3}{x^2+2x+8}$$
#
# Напишите функцию, которая получает на вход число $x$ и возвращает $y$. Сформируйте словарь с элементами $x:y$ для всех $x$ из данного списка.

# %%
x_values = [1, 13, 14, 23, 25, 34, 24, 14]

# %% [markdown]
# ## Задачи общей практики

# %% [markdown]
# # Task_5
#
# Напишите функцию 'median', которая получает на вход list с числами и возвращает медиану.
#
# ![image.png](data:image/png;base64,...)

# %%
list_1 = [1, 13, 14, 23, 25, 34, 24, 14, 100, 100000]
list_2 = [3, 5, 4, 45, 4, 2, 345, 456, 43456, 33, 1]

# %% [markdown]
# # Task_6
#
# Напишите функцию, которая получает на вход два натуральных числа $a$ и $b$. Из всех натуральных чисел, принадлежащих числовому отрезку [a; b], функция возвращает числа, имеющие ровно два различных натуральных делителя, не считая единицы и самого числа.

# %%
# test [174457; 174505]

# %% [markdown]
# # Task_7
#
# Напишите функцию, которая получает на вход два натуральных числа  𝑎  и  𝑏 . Алгоритм находит все натуральные числа, принадлежащие числовому отрезку [a; b], имеющие ровно 4 различных натуральных делителя, не считая единицы и самого числа. Функция возвращает словарь, где ключи - это найденные числа, а в качестве значений хранятся списки с делителями в порядке возрастания.

# %%
# test [185 311; 185 330]

# %% [markdown]
# # Task_8
#
# Напишем ассистент для пользователя который покупает ноутбук.
#
# Базовая модель имеет процессор Intel i3. Вот список брендов и их базовые стоимости представленные в виде двух строк:
#
#
#
# ```
# brand = 'Acer, Asus, Honor, HP, Lenovo'
# price = '20 000, 35 000, 50 000, 40 000, 25 000'
# ```
#
#
# Модель на процессоре i5 стоит дороже базовой на 20%, с i7 на 45%. Пользователь вводит имя бренда, и если такого брэнда нет, то программа об этом сообщает. Для бренда, который в наличии, программа выводит следующее:
#
#
#
# ```
# Aser:
#
#     i3:   20 000 сом.
#     i5:   ...... сом.
#     i7:   ...... сом.
# ```

# %%
brand = 'Acer, Asus, Honor, HP, Lenovo'
price = '20 000, 35 000, 50 000, 40 000, 25 000'

# %% [markdown]
# # Task_9
#
# Напишите функции для вычисления данных уравненений:
#
# 1. $y= \sin(x) $
# 2. $y = log(x)$
#
# Задекорируйте эти функции для нахождения производной в точке.

# %%
import numpy as np

# %%
def sin_(x:float)->float:
  return np.sin(x)

def log_(x:float)->float:
  return np.log(x)

# %% [markdown]
# # Task_10
#
# 1. Напишите функцию, которая возвращает значение написанного ниже уравнения.
# 2. Задекорируйте эту функцию, чтобы она возвращала градиент в заданной точке $x, y$.

# %% [markdown]
# $$ z = \frac{-5e^x}{(1+e^x)^2} - \frac{10e^{y-5}}{(1+e^{y-5})^2} $$

# %% [markdown]
# $$ z = f(x, y) $$
#
# $$\frac{\partial z}{\partial x} = \lim\limits_{\bigtriangleup x \to 0} \frac{f(x + \bigtriangleup x, y) - f(x, y)}{\bigtriangleup x}$$
#
# $$\frac{\partial z}{\partial y} = \lim\limits_{\bigtriangleup y \to 0} \frac{f(x, y + \bigtriangleup y) - f(x, y)}{\bigtriangleup y}$$
#
# $$ \bigtriangledown_{f(x, y)} = \left(\!
#     \begin{array}{c}
#       \frac{\partial z}{\partial x} \\
#       \frac{\partial z}{\partial y}
#     \end{array}
#   \!\right)$$

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
